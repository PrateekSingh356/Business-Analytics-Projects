# %% [markdown]
# # Power Bi Project
# # Student Spend Analysis

# %% [markdown]
# ![ssa1.png](attachment:ssa1.png)

# %% [markdown]
# ![ssd2.png](attachment:ssd2.png)

# %% [markdown]
# ![ssd3.png](attachment:ssd3.png)
