# %% [markdown]
# # PowerBi Project
# # Product Analysis

# %% [markdown]
# ![pa1.png](attachment:pa1.png)

# %% [markdown]
# ![pa2.png](attachment:pa2.png)

# %% [markdown]
# ![pa3.png](attachment:pa3.png)

# %% [markdown]
# ![pa5.png](attachment:pa5.png)

# %% [markdown]
# ![pa7.png](attachment:pa7.png)

# %% [markdown]
# ![pa6.png](attachment:pa6.png)
